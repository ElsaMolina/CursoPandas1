# %% [markdown]
# <a href="https://colab.research.google.com/github/ElsaMolina/CursosPandas/blob/main/Pandas_E_S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1- Leyendo archivos CSV

# %% [markdown]
# ## Importando archivos CSV

# %%
import pandas as pd

# %%
datos = pd.read_csv('superstore_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-4888b7aec79d> in <cell line: 0>()
# ----> 1 datos = pd.read_csv('superstore_data.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'superstore_data.csv'

# %%
datos.head()

# %% [markdown]
# ## Parámetros de la función read_csv

# %%
#Utilizando el parámetro sep
datos_punto_coma = pd.read_csv('superstore_data_punto_coma.csv', sep=';')

# %%
datos_punto_coma.head()

# %%
#Utilizando el parámetro nrows
datos_primeras_lineas = pd.read_csv('superstore_data.csv', nrows=5)
datos_primeras_lineas

# %%
#Utilizando el parámetro usecols
datos_seleccion = pd.read_csv('superstore_data.csv', usecols=['Id','Year_Birth','Income' ])
datos_seleccion

# %%
datos_seleccion = pd.read_csv('superstore_data.csv', usecols=[0,1,4 ])
datos_seleccion

# %% [markdown]
# ## Escribiendo archivos CSV

# %%
datos_seleccion.to_csv('clientes_mercado.csv')

# %%
cliente_mercado = pd.read_csv('clientes_mercado.csv')
cliente_mercado

# %%
datos_seleccion.to_csv('datos_clientes_mercado.csv', index=False)

# %%
datos_mercado = pd.read_csv('datos_clientes_mercado.csv')
datos_mercado

# %% [markdown]
# # Aula 2 - Leyendo archivos EXCEL

# %% [markdown]
# ## Importando archivos Excel

# %%
import pandas as pd

# %%
arcivos_excel = 'emisiones_CO2.xlsx'

# %%
datos_co2= pd.read_excel(arcivos_excel)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-f82a64e174ad> in <cell line: 0>()
# ----> 1 datos_co2= pd.read_excel(arcivos_excel)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'emisiones_CO2.xlsx'

# %%
datos_co2.head()

# %%
pd.ExcelFile(arcivos_excel).sheet_names

# %% [markdown]
# ## Parámetros de la función read_excel

# %%
percapita =pd.read_excel(arcivos_excel, sheet_name='emisiones_percapita')

# %%
percapita.tail()

# %%
fuentes =pd.read_excel(arcivos_excel, sheet_name='fuentes')

# %%
fuentes.tail()

# %%
intervalo =pd.read_excel(arcivos_excel, sheet_name='emisiones_C02',usecols='A:D')

# %%
intervalo

# %%
intervalo_2 =pd.read_excel(arcivos_excel, sheet_name='emisiones_C02',usecols='A:D', nrows=10)

# %%
intervalo_2

# %% [markdown]
# ## Escribiendo archivo Excel

# %%
intervalo.to_excel('co2_percapita.xlsx',index=False)

# %%
pd.read_excel('co2_percapita.xlsx')

# %% [markdown]
# ## Leyendo datos de Google Sheets

# %%
https://docs.google.com/spreadsheets/d/1fM-6EHQOzH3YHMov5KIQdai-3yalCisw/edit?usp=sharing&ouid=108925122500076388025&rtpof=true&sd=true

# %%
sheet_id = '1fM-6EHQOzH3YHMov5KIQdai-3yalCisw'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_co2_sheets = pd.read_csv(url)

# %%
datos_co2_sheets

# %%
sheet_id = '1fM-6EHQOzH3YHMov5KIQdai-3yalCisw'
sheet_name = 'emisiones_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheets = pd.read_csv(url_percapita)
percapita_sheets

# %% [markdown]
# # Aula 3 - Leyendo archivos JSON

# %% [markdown]
# ## Importando archivos JSON

# %%
import pandas as pd

# %%
datos_pacientes =pd.read_json('pacientes.json')

# %%
datos_pacientes

# %%
datos_pacientes_2 =pd.read_json('pacientes_2.json')
datos_pacientes_2

# %% [markdown]
# ## Normalizando archivos JSON

# %%
df_normalizado = pd.json_normalize(datos_pacientes_2['Pacientes'])

# %%
df_normalizado

# %% [markdown]
# ## Escribiendo archivos JSON

# %%
df_normalizado.to_json('historico_pacientes_norm.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-9245801eb32f> in <cell line: 0>()
# ----> 1 df_normalizado.to_json('historico_pacientes_norm.json')
#
# NameError: name 'df_normalizado' is not defined

# %%
pd.read_json('historico_pacientes_norm.json')

# %% [markdown]
# # Aula 4 - Leyendo archivos web

# %% [markdown]
# ## Importando páginas web

# %%
import pandas as pd

# %%
datos_html = pd.read_html('peliculas_wikipedia.html')

# %%
datos_html

# %%
type(datos_html)

# %%
top_peliculas = datos_html[1]

# %%
top_peliculas

# %% [markdown]
# ## Escribiendo archivos HTML

# %%
top_peliculas.to_html('top_peliculas.html', index=False)

# %%
pd.read_html('top_peliculas.html')

# %%
top_peliculas.to_csv('top_peliculas_1998.csv', index=False)

# %%
datos = pd.read_csv('top_peliculas_1998.csv')
datos

# %% [markdown]
# ## Leyendo/escribiendo archivos XML

# %%
import pandas as pd

# %%
datos_imdb = pd.read_xml('imdb_top_1000.xml')

# %%
datos_imdb.head(3)

# %%
datos_imdb.to_xml('datos_imdb.xml', index= False)

# %%
pd.read_xml('datos_imdb.xml')

# %% [markdown]
# # Aula 5 - Leyendo banco de datos

# %% [markdown]
# ## Creando un banco de datos local

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine ('sqlite:///:memory')

# %% [markdown]
# ## Escribiendo en un banco de datos

# %%
import pandas as pd

# %%
archivo = 'clientes_banco.csv'

# %%
datos = pd.read_csv(archivo)

# %%
datos.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008809    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1    Departamento alquilado
# 2            1  Casa/Departamento propio
# 3            0  Casa/Departamento propio
# 4            0  Casa/Departamento propio

# %%
datos.to_sql('clientes', engine, index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-a2d239211c08> in <cell line: 0>()
# ----> 1 datos.to_sql('clientes', engine, index = False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     840
#     841     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842         return pandas_sql.to_sql(
#     843             frame,
#     844             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006         sql_engine = get_engine(engine)
#    2007
# -> 2008         table = self.prep_table(
#    2009             frame=frame,
#    2010             name=name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1910             dtype=dtype,
#    1911         )
# -> 1912         table.create()
#    1913         return table
#    1914
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in create(self)
#     984         if self.exists():
#     985             if self.if_exists == "fail":
# --> 986                 raise ValueError(f"Table '{self.name}' already exists.")
#     987             if self.if_exists == "replace":
#     988                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'clientes' already exists.

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']

# %% [markdown]
# ## Leyendo una consulta SQL

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renta = "Empleado"'

# %%
empelados = pd.read_sql(sql=text(query), con = engine.connect())

# %%
type (empelados)
# Out:
# pandas.core.frame.DataFrame

# %%
empelados
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3                Empleado        Contabilidad              2
# 4                Empleado        Contabilidad              2
# ...                   ...                 ...            ...
# 226054           Empleado                Otro              7
# 226055           Empleado                Otro              7
# 226056           Empleado  Construcción Civil              5
# 226057           Empleado  Construcción Civil              8
# 226058           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            1  Casa/Departamento propio
# 4                270000.0            1  Casa/Departamento propio
# ...                   ...          ...                       ...
# 226054           355050.0            1  Casa/Departamento propio
# 226055           355050.0            1  Casa/Departamento propio
# 226056           135000.0            1  Casa/Departamento propio
# 226057           103500.0            0  Casa/Departamento propio
# 226058           121500.0            0  Casa/Departamento propio
#
# [226059 rows x 11 columns]

# %%
empelados.to_sql('empleados', con = engine.connect(), index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-31f54f86d18b> in <cell line: 0>()
# ----> 1 empelados.to_sql('empleados', con = engine.connect(), index = False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     840
#     841     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842         return pandas_sql.to_sql(
#     843             frame,
#     844             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006         sql_engine = get_engine(engine)
#    2007
# -> 2008         table = self.prep_table(
#    2009             frame=frame,
#    2010             name=name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1910             dtype=dtype,
#    1911         )
# -> 1912         table.create()
#    1913         return table
#    1914
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in create(self)
#     984         if self.exists():
#     985             if self.if_exists == "fail":
# --> 986                 raise ValueError(f"Table '{self.name}' already exists.")
#     987             if self.if_exists == "replace":
#     988                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'empleados' already exists.

# %%
pd.read_sql_table('empleados', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3                Empleado        Contabilidad              2
# 4                Empleado        Contabilidad              2
# ...                   ...                 ...            ...
# 226054           Empleado                Otro              7
# 226055           Empleado                Otro              7
# 226056           Empleado  Construcción Civil              5
# 226057           Empleado  Construcción Civil              8
# 226058           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            1  Casa/Departamento propio
# 4                270000.0            1  Casa/Departamento propio
# ...                   ...          ...                       ...
# 226054           355050.0            1  Casa/Departamento propio
# 226055           355050.0            1  Casa/Departamento propio
# 226056           135000.0            1  Casa/Departamento propio
# 226057           103500.0            0  Casa/Departamento propio
# 226058           121500.0            0  Casa/Departamento propio
#
# [226059 rows x 11 columns]

# %%
pd.read_sql_table('empleados', con = engine.connect(), columns=['ID_Cliente', 'Grado_estudio', 'Rendimiento_anual'])
# Out:
#         ID_Cliente     Grado_estudio  Rendimiento_anual
# 0          5008804    Nivel superior           427500.0
# 1          5008805    Nivel superior           427500.0
# 2          5008806  Nivel intermedio           112500.0
# 3          5008815    Nivel superior           270000.0
# 4          5112956    Nivel superior           270000.0
# ...            ...               ...                ...
# 226054     6837905  Nivel intermedio           355050.0
# 226055     6837906  Nivel intermedio           355050.0
# 226056     6839936  Nivel intermedio           135000.0
# 226057     6840222  Nivel intermedio           103500.0
# 226058     6842885  Nivel intermedio           121500.0
#
# [226059 rows x 3 columns]

# %% [markdown]
# ## Actualizando un banco de datos

# %%
query = 'SELECT * FROM clientes'

# %%
pd.read_sql(sql=text(query), con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438458        Pensionista                Otro              0
# 438459           Empleado  Construcción Civil              8
# 438460   Business Partner              Ventas              1
# 438461        Pensionista                Otro              0
# 438462           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438458           135000.0            0  Casa/Departamento propio
# 438459           103500.0            0  Casa/Departamento propio
# 438460            54000.0            0       Vive con los padres
# 438461            72000.0            0  Casa/Departamento propio
# 438462           121500.0            0  Casa/Departamento propio
#
# [438463 rows x 11 columns]

# %%
#Borrando registros

from sqlalchemy.exc import SQLAlchemyError

query = 'DELETE FROM clientes WHERE ID_Cliente = 5008804'

try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros borrados: ", r_set.rowcount)
# Out:
# (sqlite3.OperationalError) database is locked
# [SQL: DELETE FROM clientes WHERE ID_Cliente = 5008804]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
pd.read_sql_table('clientes', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438458        Pensionista                Otro              0
# 438459           Empleado  Construcción Civil              8
# 438460   Business Partner              Ventas              1
# 438461        Pensionista                Otro              0
# 438462           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438458           135000.0            0  Casa/Departamento propio
# 438459           103500.0            0  Casa/Departamento propio
# 438460            54000.0            0       Vive con los padres
# 438461            72000.0            0  Casa/Departamento propio
# 438462           121500.0            0  Casa/Departamento propio
#
# [438463 rows x 11 columns]

# %%
#editando registros

query = 'UPDATE clientes SET Grado_estudio = "Nivel superior" WHERE ID_Cliente=5008808	'

try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros actualizados: ", r_set.rowcount)
# Out:
# (sqlite3.OperationalError) database is locked
# [SQL: UPDATE clientes SET Grado_estudio = "Nivel superior" WHERE ID_Cliente=5008808	]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']
